# %% [markdown]
# > NAME: V.P.PRANEETH REDDY REG NO: 21BCT0353
# > VIT VELLORE CAMPUS
# > SLOT: 6:00 TO 8:00 PM
# >
# > Task - 1 Create a pandas dataframe (DataFrame name as 'df') (10
# > observation and 5 features)
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>import numpy as np<br />
# df = {'Name':<br />
# ['Gaikwad','Conway','Rayudu','Dubey','Dhoni','Jadeja','Bravo','Deepak'
# ,'Thakur','Pathirana'],'Age':<br />
# [27,36,34,np.nan,32,30,34,31,39,28],'Gender':<br />
# ['M','M','M','M','M','M','M','M','M','M'],'Role':<br />
# ['BATTER','BATTER','ALL-ROUNDER','ALL-ROUNDER','WICKET-KEPPER','ALL-ROUNDER','ALL-ROUNDER','BOWLER','BOWLER','BOWLER'],'TEAM':<br />
# ['CSK','CSK','CSK','CSK','CSK','CSK','CSK','CSK','CSK','CSK']}<br />
# df</p>
# <p>{'Name': ['Gaikwad',</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Conway',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Rayudu',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Dubey',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Dhoni',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Jadeja',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Bravo',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Deepak',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Thakur',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'Pathirana'],</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><p>'Role': ['BATTER'</p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'BATTER',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'ALL-ROUNDER',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'ALL-ROUNDER',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>'WICKET-KEPPER',</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'ALL-ROUNDER',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'ALL-ROUNDER',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'BOWLER',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'BOWLER',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'BOWLER'],</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>'TEAM': ['CSK',</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="odd">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK',</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>'CSK']}</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# </tbody>
# </table>
# <blockquote>
# <p>'Age': [27, 36, 34, nan, 32, 30, 34, 31, 39, 28],<br />
# 'Gender': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M'],</p>
# <p>import pandas as pd<br />
# df = pd.DataFrame(df)<br />
# df</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Name Age Gender Role TEAM 0 Gaikwad 27.0 M BATTER CSK 1 Conway 36.0 M
# BATTER CSK 2 Rayudu 34.0 M ALL-ROUNDER CSK 3 Dubey NaN M ALL-ROUNDER CSK
# 4 Dhoni 32.0 M WICKET-KEPPER CSK 5 Jadeja 30.0 M ALL-ROUNDER CSK 6 Bravo
# 34.0 M ALL-ROUNDER CSK 7 Deepak 31.0 M BOWLER CSK 8 Thakur 39.0 M BOWLER
# CSK 9 Pathirana 28.0 M BOWLER CSK</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Task- 2 Check the info of 'df'
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>df.info()</p>
# <p>&lt;class 'pandas.core.frame.DataFrame'&gt; RangeIndex: 10 entries, 0
# to 9<br />
# Data columns (total 5 columns):<br />
# # Column Non-Null Count Dtype --- ------ -------------- ----- 0 Name 10
# non-null object 1 Age 9 non-null float64 2 Gender 10 non-null object 3
# Role 10 non-null object 4 TEAM 10 non-null object dtypes: float64(1),
# object(4)<br />
# memory usage: 528.0+ bytes</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Task 3- Check the descriptive statistics of 'df'
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>df.describe()</p>
# </blockquote>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Age count 9.000000 mean 32.333333 std 3.840573 min 27.000000 25%
# 30.000000 50% 32.000000 75% 34.000000 max 39.000000</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Task 4- check the 4th index observation with 'loc' slicing operator.
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>df.loc[3]<br />
# Name Dubey<br />
# Age NaN</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>Gender M Role ALL-ROUNDER TEAM CSK Name: 3, dtype: object</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > Task 5 - Check the null values in your 'df'
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>df.isnull().any()</p>
# <p>Name False<br />
# Age True<br />
# Gender False<br />
# Role False<br />
# TEAM False<br />
# dtype: bool</p>
# <p>df.isnull().sum()</p>
# <p>Name 0<br />
# Age 1<br />
# Gender 0<br />
# Role 0<br />
# TEAM 0<br />
# dtype: int64</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
